# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("multiTimeline.csv")

# %%
df.columns
# Out:
# Index(['Semana', 'Go: (Argentina)', 'C: (Argentina)', 'SQL: (Argentina)',
#        'R: (Argentina)', 'python: (Argentina)'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Semana', 'Go: (Argentina)', 'C: (Argentina)', 'SQL: (Argentina)',
#        'R: (Argentina)', 'python: (Argentina)'],
#       dtype='object')

# %%
plt.plot(df.index,df["Go: (Argentina)"],marker='.', color='r', label= 'Go: (Argentina')
plt.plot(df.index,df["C: (Argentina)"], marker = '.', color = 'g',label = 'C: (Argentina)')
plt.plot(df.index,df["SQL: (Argentina)"], marker = '.', color = 'w',label = 'SQL: (Argentina)')
plt.plot(df.index,df["R: (Argentina)"], marker = '.', color = 'b',label = 'R: (Argentina)')
plt.plot(df.index,df["python: (Argentina)"], marker = '.', color = 'y',label = 'python: (Argentina)')
plt.legend();

# %% [markdown]
# https://trends.google.es/trends/explore?cat=958&geo=AR&q=Go,C,SQL,R,python
# https://trends.google.es/trends/explore?cat=958&geo=AR&q=python,R,Julia,MATLAB
# https://trends.google.es/trends/explore?geo=AR&q=Full%20Stack,Data%20Science,Business%20Intelligence
# https://trends.google.es/trends/explore?geo=AR&q=Ciberseguridad,Analista%20de%20Sistemas,Desarrollador%20Full%20Stack,Soporte%20T%C3%A9cnico,Desarrollador%20WEB
