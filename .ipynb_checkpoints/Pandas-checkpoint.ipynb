# %% [markdown]
# # Pandas
# [Tutorial](https://www.youtube.com/watch?v=8ASjvOIyyl8)
# [Tutorial2](https://www.youtube.com/watch?v=zAIWnwqHGok)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1 Creando un dataFrame usando arrays

# %%
data = np.array([[1,4],[55,2],[25,25],[10,5]])

# %%
data
# Out:
# array([[ 1,  4],
#        [55,  2],
#        [25, 25],
#        [10,  5]])

# %%
pd.DataFrame(data, index=['row1','row2','row3','row4'],
            columns=['col1','col2'])
# Out:
#       col1  col2
# row1     1     4
# row2    55     2
# row3    25    25
# row4    10     5

# %% [markdown]
# ## Creando dataFrame desde diccionarios

# %%
states = ['California','Texas','Florida','New York']
population = [39613493,29730311,21944577,19299981]

# %%
dic_states = {'States':states, 'Population':population}

# %%
dic_states
# Out:
# {'States': ['California', 'Texas', 'Florida', 'New York'],
#  'Population': [39613493, 29730311, 21944577, 19299981]}

# %%
df = pd.DataFrame(dic_states)

# %%
df
# Out:
#        States  Population
# 0  California    39613493
# 1       Texas    29730311
# 2     Florida    21944577
# 3    New York    19299981

# %% [markdown]
# ## Crear un dataFrame desde un archivo excel

# %%
import time
start = time.time()
mat = pd.read_excel("C:/Users/ordonez/Documents/SAP/SAP GUI/M.xlsx")
end = time.time()
print(f"Para importar los datos SAP se tardó {end - start} segundos")
# Out:
# Para importar los datos SAP se tardó 7.716641187667847 segundos

# %%
display(mat)
# Out:
#        Material  UMB  Libre utiliz.  Punto pedido  Stock máximo  \
# 0       1011796  C/U           40.0          50.0           0.0
# 1       1030616  C/U           30.0           6.0           0.0
# 2       1033865  C/U            0.0           0.0           0.0
# 3       1000007   KG         7100.0           0.0        5000.0
# 4       1000008   KG        77808.4           0.0      240000.0
# ...         ...  ...            ...           ...           ...
# 28325   1062232  C/U            0.0           7.0           7.0
# 28326   1062233  C/U            0.0           8.0           8.0
# 28327   1062234  C/U            0.0           2.0           2.0
# 28328   1062283   KG            0.0           2.0           3.0
# 28329   1062284   KG            0.0           2.0           3.0
#
#        Tam.lote fijo CaP                   Texto breve de material  \
# 0                120  ND   LAMPARA BAJO CONSUMO 85W ROSCA E40 220V
# 1                 16  ND    RASPADOR GOMA OLIVER 8X16 PL-05-0216X1
# 2                  2  ND  JUNTA SELLANTE GORE TEX DE 3/4" x 9,14 M
# 3                  0  ND                    BACTERICIDA BUSSAN 881
# 4                  0  P5              CAL HIDRATADA. ENV. 1000 KG.
# ...              ...  ..                                       ...
# 28325              0  V1                     ASIENTO SIWO 20" EPDM
# 28326              0  V1                     ASIENTO SIWO 24" EPDM
# 28327              0  V1                  ASIENTO SIWO DE 32" EPDM
# 28328              0  V1  PASTA CERAMICA REPAIR PUTTY DEVCOM X 1KG
# 28329              0  V1       PASTA DE TITANIO PUTTY DEVCOM X 1KG
#
#       NºMaterial antiguo   Ce.  ... Grupo art.  \
# 0               39512108  1001  ...  ELEC390IL
# 1               76211291  1001  ...  RASP762GO
# 2               87491015  1001  ...  JUNT870GO
# 3               01110105  1002  ...      30007
# 4               01120104  1001  ...  CRUD013PS
# ...                  ...   ...  ...        ...
# 28325                NaN  1001  ...  VALV370AC
# 28326                NaN  1001  ...  VALV370AC
# 28327                NaN  1001  ...  VALV370AC
# 28328                NaN  1001  ...  ABRA430PQ
# 28329                NaN  1001  ...  ABRA430PQ
#
#                      Grupo de artículos  GCp Cantidad base  ABC     Creado  \
# 0      Material eléctrico - Iluminación  D40             1    B 2013-11-08
# 1                  Raspador Goma Oliver  D49             1    B 2013-11-08
# 2                   Junta Sellante Gore  D49             1    C 2013-11-08
# 3                    PRODUCTOS QUÍMICOS  D66             1  NaN 2013-11-08
# 4                   Prod. Químico Crudo  D42             1    A 2013-11-08
# ...                                 ...  ...           ...  ...        ...
# 28325             valvulas - accesorios  D62             1  NaN 2022-03-18
# 28326             valvulas - accesorios  D62             1  NaN 2022-03-18
# 28327             valvulas - accesorios  D62             1  NaN 2022-03-18
# 28328                  Pastas abrasivas  D45             1  NaN 2022-03-23
# 28329                  Pastas abrasivas  D45             1  NaN 2022-03-23
#
#        Indicador: Parte crítica Val.redondeo NºFb  PzE
# 0                            No          0.0  NaN   60
# 1                            No          0.0  NaN   60
# 2                            No          0.0  NaN   60
# 3                            No          0.0  NaN  150
# 4                            No      24000.0  NaN   30
# ...                         ...          ...  ...  ...
# 28325                        No          0.0  NaN   60
# 28326                        No          0.0  NaN   60
# 28327                        No          0.0  NaN   60
# 28328                        No          0.0  NaN   60
# 28329                        No          0.0  NaN   60
#
# [28330 rows x 23 columns]

# %%
mat.columns
# Out:
# Index(['Material', 'UMB', 'Libre utiliz.', 'Punto pedido', 'Stock máximo',
#        'Tam.lote fijo', 'CaP', 'Texto breve de material', 'NºMaterial antiguo',
#        'Ce.', 'Almacén', 'PrMedioVar', 'Jquía.productos', 'Grupo art.',
#        'Grupo de artículos', 'GCp', 'Cantidad base', 'ABC', 'Creado',
#        'Indicador: Parte crítica', 'Val.redondeo', 'NºFb', 'PzE'],
#       dtype='object')

# %%
mat.dtypes
# Out:
# Material                             int64
# UMB                                 object
# Libre utiliz.                      float64
# Punto pedido                       float64
# Stock máximo                       float64
# Tam.lote fijo                        int64
# CaP                                 object
# Texto breve de material             object
# NºMaterial antiguo                  object
# Ce.                                  int64
# Almacén                             object
# PrMedioVar                         float64
# Jquía.productos                     object
# Grupo art.                          object
# Grupo de artículos                  object
# GCp                                 object
# Cantidad base                        int64
# ABC                                 object
# Creado                      datetime64[ns]
# Indicador: Parte crítica            object
# Val.redondeo                       float64
# NºFb                                object
# PzE                                  int64
# dtype: object

# %%
mat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28330 entries, 0 to 28329
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Material                  28330 non-null  int64
#  1   UMB                       28330 non-null  object
#  2   Libre utiliz.             28330 non-null  float64
#  3   Punto pedido              28330 non-null  float64
#  4   Stock máximo              28330 non-null  float64
#  5   Tam.lote fijo             28330 non-null  int64
#  6   CaP                       28330 non-null  object
#  7   Texto breve de material   28330 non-null  object
#  8   NºMaterial antiguo        21621 non-null  object
#  9   Ce.                       28330 non-null  int64
#  10  Almacén                   28330 non-null  object
#  11  PrMedioVar                28330 non-null  float64
#  12  Jquía.productos           28330 non-null  object
#  13  Grupo art.                28330 non-null  object
#  14  Grupo de artículos        28330 non-null  object
#  15  GCp                       25608 non-null  object
#  16  Cantidad base             28330 non-null  int64
#  17  ABC                       17073 non-null  object
#  18  Creado                    28330 non-null  datetime64[ns]
#  19  Indicador: Parte crítica  28330 non-null  object
#  20  Val.redondeo              28330 non-null  float64
#  21  NºFb                      2204 non-null   object
#  22  PzE                       28330 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(5), object(12)
# memory usage: 5.0+ MB

# %%
mat.describe()
# Out:
#            Material  Libre utiliz.  Punto pedido  Stock máximo  Tam.lote fijo  \
# count  2.833000e+04   2.833000e+04  2.833000e+04  2.833000e+04   28330.000000
# mean   1.026406e+06   1.112488e+03  4.799462e+02  7.950649e+02       0.004871
# std    1.915385e+04   6.973690e+04  1.552056e+04  3.342601e+04       0.719352
# min    1.000007e+06   0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    1.010366e+06   1.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 50%    1.025022e+06   3.000000e+00  1.000000e+00  2.000000e+00       0.000000
# 75%    1.035426e+06   1.600000e+01  4.000000e+00  1.000000e+01       0.000000
# max    2.000040e+06   1.105000e+07  1.100000e+06  5.000000e+06     120.000000
#
#                 Ce.    PrMedioVar  Cantidad base  Val.redondeo           PzE
# count  28330.000000  2.833000e+04   28330.000000  28330.000000  28330.000000
# mean    1003.642429  1.738441e+04       1.270702     14.391478     70.356618
# std        2.685497  1.633952e+05      30.872523    383.183999     28.692848
# min     1001.000000  0.000000e+00       1.000000      0.000000      0.000000
# 25%     1001.000000  0.000000e+00       1.000000      0.000000     60.000000
# 50%     1002.000000  3.096300e+02       1.000000      0.000000     60.000000
# 75%     1007.000000  3.268430e+03       1.000000      1.000000     60.000000
# max     1007.000000  1.137688e+07    5000.000000  28000.000000    300.000000

# %% [markdown]
# ## Borrar los materiales de los almacenes 1140 y 1142 del centro 1002

# %%
indexABorrar = materiales[(materiales['Ce.']==1002) & (materiales['Almacén'].isin(['1141','1140']))].index
materiales.drop(indexABorrar, inplace=True)

# %% [markdown]
# ## Creamos el id_mat

# %%
mat["id_mat"] = mat["Almacén"] + mat["Material"].astype(str)
mat.set_index('id_mat', inplace=True)

# %% [markdown]
# ## Filtrados de columnas

# %%
mat["Material"]
# Out:
# 0        1011796
# 1        1030616
# 2        1033865
# 3        1000007
# 4        1000008
#           ...
# 28325    1062232
# 28326    1062233
# 28327    1062234
# 28328    1062283
# 28329    1062284
# Name: Material, Length: 28330, dtype: int64

# %%
mat[['Material','Almacén', 'PrMedioVar','Libre utiliz.']] # Paso una lista con los nom.de col.
# Out:
#        Material Almacén  PrMedioVar  Libre utiliz.
# 0       1011796    1126     2274.07           40.0
# 1       1030616    1126     6056.65           30.0
# 2       1033865    1126   103612.80            0.0
# 3       1000007    1129       12.41         7100.0
# 4       1000008    1125        9.65        77808.4
# ...         ...     ...         ...            ...
# 28325   1062232    1126        0.00            0.0
# 28326   1062233    1126        0.00            0.0
# 28327   1062234    1126        0.00            0.0
# 28328   1062283    1126        0.00            0.0
# 28329   1062284    1126        0.00            0.0
#
# [28330 rows x 4 columns]

# %% [markdown]
# ## Filtrado de filas

# %%
mat.iloc[0]
# Out:
# Material                                                    1011796
# UMB                                                             C/U
# Libre utiliz.                                                  40.0
# Punto pedido                                                   50.0
# Stock máximo                                                    0.0
# Tam.lote fijo                                                   120
# CaP                                                              ND
# Texto breve de material     LAMPARA BAJO CONSUMO 85W ROSCA E40 220V
# NºMaterial antiguo                                         39512108
# Ce.                                                            1001
# Almacén                                                        1126
# PrMedioVar                                                  2274.07
# Jquía.productos                                          0003900395
# Grupo art.                                                ELEC390IL
# Grupo de artículos                 Material eléctrico - Iluminación
# GCp                                                             D40
# Cantidad base                                                     1
# ABC                                                               B
# Creado                                          2013-11-08 00:00:00
# Indicador: Parte crítica                                         No
# Val.redondeo                                                    0.0
# NºFb                                                            NaN
# PzE                                                              60
# Name: 0, dtype: object

# %%
mat.iloc[0:3]
# Out:
#    Material  UMB  Libre utiliz.  Punto pedido  Stock máximo  Tam.lote fijo  \
# 0   1011796  C/U           40.0          50.0           0.0            120
# 1   1030616  C/U           30.0           6.0           0.0             16
# 2   1033865  C/U            0.0           0.0           0.0              2
#
#   CaP                   Texto breve de material NºMaterial antiguo   Ce.  ...  \
# 0  ND   LAMPARA BAJO CONSUMO 85W ROSCA E40 220V           39512108  1001  ...
# 1  ND    RASPADOR GOMA OLIVER 8X16 PL-05-0216X1           76211291  1001  ...
# 2  ND  JUNTA SELLANTE GORE TEX DE 3/4" x 9,14 M           87491015  1001  ...
#
#   Grupo art.                Grupo de artículos  GCp Cantidad base ABC  \
# 0  ELEC390IL  Material eléctrico - Iluminación  D40             1   B
# 1  RASP762GO              Raspador Goma Oliver  D49             1   B
# 2  JUNT870GO               Junta Sellante Gore  D49             1   C
#
#       Creado  Indicador: Parte crítica Val.redondeo NºFb PzE
# 0 2013-11-08                        No          0.0  NaN  60
# 1 2013-11-08                        No          0.0  NaN  60
# 2 2013-11-08                        No          0.0  NaN  60
#
# [3 rows x 23 columns]

# %%
mat.loc[['11261004756','11261001167','11281061933']]
# Out:
#              Material  UMB  Libre utiliz.  Punto pedido  Stock máximo  \
# id_mat
# 11261004756   1004756  C/U        41640.0       19600.0       47800.0
# 11261001167   1001167  C/U        16000.0        4700.0       11600.0
# 11281061933   1061933  C/U            0.0           4.0           9.0
#
#              Tam.lote fijo CaP                   Texto breve de material  \
# id_mat
# 11261004756              0  V1  VASO PLAST. DESCARTABLE CAPACIDAD: 180CC
# 11261001167              0  V1  PADS FIBRA DE VIDRIO SARTORIUS DIAM.47MM
# 11281061933              0  V1        CUCHILLA DE CORTE TRANSVERSAL SUP.
#
#             NºMaterial antiguo   Ce.  ... Grupo art.  \
# id_mat                                ...
# 11261004756           27214055  1001  ...  INTE270DS
# 11261001167           14144448  1001  ...  LABO142AC
# 11281061933                NaN  1002  ...      10056
#
#                                   Grupo de artículos  GCp Cantidad base  ABC  \
# id_mat
# 11261004756  Articulos de intendencia - descartables  D45             1    B
# 11261001167                 Elementos de Laboratorio  D69             1    B
# 11281061933                               CONVERSION  D59             1  NaN
#
#                 Creado  Indicador: Parte crítica Val.redondeo NºFb  PzE
# id_mat
# 11261004756 2013-11-08                        No          0.0  NaN   60
# 11261001167 2013-11-08                        No          0.0  NaN   90
# 11281061933 2022-02-10                        No          0.0  NaN  150
#
# [3 rows x 23 columns]

# %%
mat.loc[['11261004756','11261001167','11281061933'],['Material','Almacén', 'PrMedioVar','Libre utiliz.']]
# Out:
#              Material Almacén  PrMedioVar  Libre utiliz.
# id_mat
# 11261004756   1004756    1126        2.49        41640.0
# 11261001167   1001167    1126       27.75        16000.0
# 11281061933   1061933    1128        0.00            0.0

# %%
mat[(mat['PrMedioVar']<10000) & (mat['Almacén']=='1126')]
# Out:
#              Material  UMB  Libre utiliz.  Punto pedido  Stock máximo  \
# id_mat
# 11261011796   1011796  C/U           40.0          50.0           0.0
# 11261030616   1030616  C/U           30.0           6.0           0.0
# 11261001103   1001103    L           27.0           6.0          25.0
# 11261001104   1001104    G         6800.0         500.0        2000.0
# 11261001106   1001106    L           13.5           5.0          10.0
# ...               ...  ...            ...           ...           ...
# 11261062232   1062232  C/U            0.0           7.0           7.0
# 11261062233   1062233  C/U            0.0           8.0           8.0
# 11261062234   1062234  C/U            0.0           2.0           2.0
# 11261062283   1062283   KG            0.0           2.0           3.0
# 11261062284   1062284   KG            0.0           2.0           3.0
#
#              Tam.lote fijo CaP                   Texto breve de material  \
# id_mat
# 11261011796            120  ND   LAMPARA BAJO CONSUMO 85W ROSCA E40 220V
# 11261030616             16  ND    RASPADOR GOMA OLIVER 8X16 PL-05-0216X1
# 11261001103              0  V1  ACIDO ACETICO GLACIAL P.A. MERCK 63MALL.
# 11261001104              0  V1        ACIDO ORTOFOSFORICO P.A. MERCK 573
# 11261001106              0  V1   ACIDO NITRICO P.A. ISO AL 65% MCA.MERCK
# ...                    ...  ..                                       ...
# 11261062232              0  V1                     ASIENTO SIWO 20" EPDM
# 11261062233              0  V1                     ASIENTO SIWO 24" EPDM
# 11261062234              0  V1                  ASIENTO SIWO DE 32" EPDM
# 11261062283              0  V1  PASTA CERAMICA REPAIR PUTTY DEVCOM X 1KG
# 11261062284              0  V1       PASTA DE TITANIO PUTTY DEVCOM X 1KG
#
#             NºMaterial antiguo   Ce.  ... Grupo art.  \
# id_mat                                ...
# 11261011796           39512108  1001  ...  ELEC390IL
# 11261030616           76211291  1001  ...  RASP762GO
# 11261001103           14110027  1001  ...  LABO141PS
# 11261001104           14110043  1001  ...  LABO140PQ
# 11261001106           14110100  1001  ...  LABO140PQ
# ...                        ...   ...  ...        ...
# 11261062232                NaN  1001  ...  VALV370AC
# 11261062233                NaN  1001  ...  VALV370AC
# 11261062234                NaN  1001  ...  VALV370AC
# 11261062283                NaN  1001  ...  ABRA430PQ
# 11261062284                NaN  1001  ...  ABRA430PQ
#
#                            Grupo de artículos  GCp Cantidad base  ABC  \
# id_mat
# 11261011796  Material eléctrico - Iluminación  D40             1    B
# 11261030616              Raspador Goma Oliver  D49             1    B
# 11261001103  Precursor Químico de Laboratorio  D42             1    C
# 11261001104   Producto Químico de Laboratorio  D42             1    D
# 11261001106   Producto Químico de Laboratorio  D42             1    D
# ...                                       ...  ...           ...  ...
# 11261062232             valvulas - accesorios  D62             1  NaN
# 11261062233             valvulas - accesorios  D62             1  NaN
# 11261062234             valvulas - accesorios  D62             1  NaN
# 11261062283                  Pastas abrasivas  D45             1  NaN
# 11261062284                  Pastas abrasivas  D45             1  NaN
#
#                 Creado  Indicador: Parte crítica Val.redondeo NºFb PzE
# id_mat
# 11261011796 2013-11-08                        No          0.0  NaN  60
# 11261030616 2013-11-08                        No          0.0  NaN  60
# 11261001103 2013-11-08                        No          1.0  NaN  75
# 11261001104 2013-11-08                        No          1.0  NaN  75
# 11261001106 2013-11-08                        No          2.5  NaN  75
# ...                ...                       ...          ...  ...  ..
# 11261062232 2022-03-18                        No          0.0  NaN  60
# 11261062233 2022-03-18                        No          0.0  NaN  60
# 11261062234 2022-03-18                        No          0.0  NaN  60
# 11261062283 2022-03-23                        No          0.0  NaN  60
# 11261062284 2022-03-23                        No          0.0  NaN  60
#
# [6844 rows x 23 columns]

# %%
mat.columns

# %% [markdown]
# ## Busca si contiene una cadena de texto

# %%
mat[mat['Texto breve de material'].str.contains('6206')]
# Out:
#              Material  UMB  Libre utiliz.  Punto pedido  Stock máximo  \
# id_mat
# 11281009258   1009258  C/U           23.0           1.0           5.0
# 11261009289   1009289  C/U          643.0         140.0         340.0
# 11281009304   1009304  C/U            2.0           1.0           2.0
# 11241024265   1024265  C/U           23.0           2.0          10.0
#
#              Tam.lote fijo CaP                 Texto breve de material  \
# id_mat
# 11281009258              0  V1                        RODAMTO,BOL 6206
# 11261009289              0  V1            RODAM. DE BOLAS SKF 6206 2RS
# 11281009304              0  V1                ROD.DE BOLAS SKF 6206 NR
# 11241024265              0  V1  RODAMIENTO TRANS. 96100-62060-00 CUATR
#
#             NºMaterial antiguo   Ce.  ... Grupo art.       Grupo de artículos  \
# id_mat                                ...
# 11281009258           38214060  1002  ...  RODA380BO      Rodamientos - bolas
# 11261009289           38214623  1001  ...  RODA380BO      Rodamientos - bolas
# 11281009304           38214821  1002  ...  RODA380BO      Rodamientos - bolas
# 11241024265           63570774  1007  ...  VEHI630HO  Vehículos - cuatriciclo
#
#              GCp Cantidad base ABC     Creado  Indicador: Parte crítica  \
# id_mat
# 11281009258  D53             1   D 2013-11-08                        No
# 11261009289  D53             1   B 2013-11-08                        No
# 11281009304  D53             1   D 2013-11-08                        No
# 11241024265  D18             1   C 2013-11-08                        No
#
#             Val.redondeo            NºFb PzE
# id_mat
# 11281009258          0.0             NaN  60
# 11261009289          0.0             NaN  60
# 11281009304          0.0             NaN  60
# 11241024265          1.0  96100-62060-00  60
#
# [4 rows x 23 columns]

# %% [markdown]
# ## Para buscar por varios textos

# %%
columna = 'Texto breve de material'
texto1 = 'JUNTA'
texto2 = '1929'

dfBusqueda2 = materiales[(materiales[columna].str.contains(texto1,case=False)) & (materiales[columna].str.contains(texto2,case=False))][['Material','Texto breve de material','Ce.','Almacén','Grupo de artículos', 'GCp']]
dfBusqueda2.to_excel('C:/Users/ordonez/Documents/SAP/SAP GUI/busqueda2.xlsx')

# %% [markdown]
# ## Apply

# %%
import random
def stockCero(stock):
    resultado = stock == 0.0
    return resultado

mat["stockCero"] = mat['Libre utiliz.'].apply(stockCero)
mat.head(10)
# Out:
#              Material  UMB  Libre utiliz.  Punto pedido  Stock máximo  \
# id_mat
# 11261011796   1011796  C/U           40.0          50.0           0.0
# 11261030616   1030616  C/U           30.0           6.0           0.0
# 11261033865   1033865  C/U            0.0           0.0           0.0
# 11291000007   1000007   KG         7100.0           0.0        5000.0
# 11251000008   1000008   KG        77808.4           0.0      240000.0
# 11251000009   1000009   KG        18085.2           0.0           0.0
# 11251000010   1000010   KG        10350.0           0.0           0.0
# 11291000011   1000011   KG          900.0         450.0         900.0
# 11281000012   1000012   KG          950.0        1000.0        8000.0
# 11251000014   1000014   KG          400.0           0.0           0.0
#
#              Tam.lote fijo CaP                   Texto breve de material  \
# id_mat
# 11261011796            120  ND   LAMPARA BAJO CONSUMO 85W ROSCA E40 220V
# 11261030616             16  ND    RASPADOR GOMA OLIVER 8X16 PL-05-0216X1
# 11261033865              2  ND  JUNTA SELLANTE GORE TEX DE 3/4" x 9,14 M
# 11291000007              0  ND                    BACTERICIDA BUSSAN 881
# 11251000008              0  P5              CAL HIDRATADA. ENV. 1000 KG.
# 11251000009              0  P8                 CAL HIDRATADA. ENV.25 KG.
# 11251000010              0  P5              FLOCULANTE P/CLARIIF DE JUGO
# 11291000011              0  VB                   DISPERSANTE BUSPERSE 47
# 11281000012              0  VB                     HIDROSULFITO DE SODIO
# 11251000014              0  P8             ANTIVISCOSO SURFAC88  T-200KG
#
#             NºMaterial antiguo   Ce.  ...  \
# id_mat                                ...
# 11261011796           39512108  1001  ...
# 11261030616           76211291  1001  ...
# 11261033865           87491015  1001  ...
# 11291000007           01110105  1002  ...
# 11251000008           01120104  1001  ...
# 11251000009           01120120  1001  ...
# 11251000010           01120252  1001  ...
# 11291000011           01130152  1002  ...
# 11281000012           01130202  1002  ...
# 11251000014           01130400  1001  ...
#
#                                        Grupo de artículos  GCp Cantidad base  \
# id_mat
# 11261011796              Material eléctrico - Iluminación  D40             1
# 11261030616                          Raspador Goma Oliver  D49             1
# 11261033865                           Junta Sellante Gore  D49             1
# 11291000007                            PRODUCTOS QUÍMICOS  D66             1
# 11251000008                           Prod. Químico Crudo  D42             1
# 11251000009                            Insu Pco Refineria  D42             1
# 11251000010                     Insumo Químico para crudo  D66             1
# 11291000011                     Insumo Químico para crudo  D66             1
# 11281000012                      MATERIA PRIMA (COMPRADA)  D65             1
# 11251000014  Insumo Quimicos comunes a todos los negocios  D66             1
#
#              ABC     Creado Indicador: Parte crítica  Val.redondeo NºFb  PzE  \
# id_mat
# 11261011796    B 2013-11-08                       No           0.0  NaN   60
# 11261030616    B 2013-11-08                       No           0.0  NaN   60
# 11261033865    C 2013-11-08                       No           0.0  NaN   60
# 11291000007  NaN 2013-11-08                       No           0.0  NaN  150
# 11251000008    A 2013-11-08                       No       24000.0  NaN   30
# 11251000009    A 2013-11-08                       No        1000.0  NaN   30
# 11251000010    A 2013-11-08                       No        1000.0  NaN   90
# 11291000011    B 2013-11-08                       No           0.0  NaN   90
# 11281000012    B 2013-11-08                       No           0.0  NaN   45
# 11251000014    B 2013-11-08                       No         200.0  NaN   45
#
#             stockCero
# id_mat
# 11261011796     False
# 11261030616     False
# 11261033865      True
# 11291000007     False
# 11251000008     False
# 11251000009     False
# 11251000010     False
# 11291000011     False
# 11281000012     False
# 11251000014     False
#
# [10 rows x 24 columns]

# %%
mat[["stockCero",'Libre utiliz.']]
# Out:
#              stockCero  Libre utiliz.
# id_mat
# 11261011796      False           40.0
# 11261030616      False           30.0
# 11261033865       True            0.0
# 11291000007      False         7100.0
# 11251000008      False        77808.4
# ...                ...            ...
# 11261062232       True            0.0
# 11261062233       True            0.0
# 11261062234       True            0.0
# 11261062283       True            0.0
# 11261062284       True            0.0
#
# [28330 rows x 2 columns]

# %%
def calculoValor(fila):
    resultado = fila['Libre utiliz.'] * fila['PrMedioVar']
    return resultado

mat['valor'] = mat.apply(calculoValor, axis=1)

# %%
mat[['Material','Libre utiliz.','PrMedioVar','valor']].head()
# Out:
#              Material  Libre utiliz.  PrMedioVar      valor
# id_mat
# 11261011796   1011796           40.0     2274.07   90962.80
# 11261030616   1030616           30.0     6056.65  181699.50
# 11261033865   1033865            0.0   103612.80       0.00
# 11291000007   1000007         7100.0       12.41   88111.00
# 11251000008   1000008        77808.4        9.65  750851.06

# %% [markdown]
# ## Agrupación de datos

# %%
mat.groupby("Almacén").mean()
# Out:
#              Material  Libre utiliz.  Punto pedido   Stock máximo  \
# Almacén
# 1124     1.031411e+06      62.547751     19.291971      60.063339
# 1125     1.010637e+06    8431.982209   2336.325799    9427.817151
# 1126     1.022605e+06     190.572822     50.148780     158.279447
# 1128     1.024990e+06      35.552330     10.517236      39.955791
# 1129     1.019890e+06   18099.993295  26249.482095   31172.392857
# 1131     1.004184e+06   13240.258222  89273.024667  132333.333333
# 1133     1.000083e+06  804120.000000      0.000000       0.000000
# 1137     1.007582e+06    1371.751389    891.851852    1782.592593
# 1140     1.022430e+06   59943.825701   5550.256061    6273.532576
# 1141     1.033839e+06     441.235563    272.836645     551.920971
# 11JU     1.022825e+06      13.777778      3.269841       6.650794
# 11JV     1.016801e+06     458.266038    137.490566     395.547170
#
#          Tam.lote fijo          Ce.    PrMedioVar  Cantidad base  \
# Almacén
# 1124          0.000000  1007.000000   6038.262875       1.000000
# 1125          0.000000  1001.000000   3413.110242       1.000000
# 1126          0.017274  1001.000000  15402.375596       1.000000
# 1128          0.000000  1002.000000  35871.039543       1.088340
# 1129          0.000000  1002.000000  78430.135268      21.824405
# 1131          0.000000  1002.000000     51.854444       1.000000
# 1133          0.000000  1002.000000      4.300000       1.000000
# 1137          0.000000  1003.000000   1607.517963       1.000000
# 1140          0.000000  1002.833333   2495.562765       1.000000
# 1141          0.000000  1003.845475   3807.851722       1.000000
# 11JU          0.000000  1003.000000   2021.448095       1.000000
# 11JV          0.000000  1003.000000    484.149245       1.000000
#
#          Val.redondeo        PzE  stockCero         valor
# Almacén
# 1124         2.701361  62.591907   0.262154  5.964444e+04
# 1125       370.292707  62.179487   0.223647  5.801741e+05
# 1126         6.497455  76.149456   0.167731  8.520299e+04
# 1128         0.969754  77.639017   0.179703  9.780294e+04
# 1129        89.285714  59.285714   0.250000  5.872399e+07
# 1131      3111.111111  47.777778   0.333333  9.052066e+05
# 1133         0.000000  60.000000   0.000000  3.457716e+06
# 1137         0.018519  65.000000   0.648148  1.067595e+06
# 1140         4.515152  61.818182   0.185606  3.970368e+05
# 1141         0.245033  59.900662   0.415011  9.237781e+04
# 11JU         0.031746  58.571429   0.238095  2.514703e+04
# 11JV         0.037736  67.924528   0.150943  9.928060e+04

# %%
agrupado = mat.groupby("Almacén").agg({
    'Libre utiliz.': 'mean',
    'PrMedioVar': 'max',
    'PzE': 'min',
    'Creado': 'max'
})

# %%
agrupado
# Out:
#          Libre utiliz.   PrMedioVar  PzE     Creado
# Almacén
# 1124         62.547751   1763961.54    0 2022-03-18
# 1125       8431.982209    163000.00    0 2022-01-04
# 1126        190.572822   8662280.10    0 2022-03-23
# 1128         35.552330  11376883.98    0 2022-03-18
# 1129      18099.993295   6757389.01    0 2021-11-19
# 1131      13240.258222       129.46   10 2013-12-26
# 1133     804120.000000         4.30   60 2013-11-08
# 1137       1371.751389     26972.02    0 2021-09-27
# 1140      59943.825701     94635.37    0 2022-01-10
# 1141        441.235563    653662.61    0 2021-04-05
# 11JU         13.777778     16250.00    0 2020-02-20
# 11JV        458.266038      2259.84    0 2021-08-06

# %%
agrupado['PrMedioVar'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Almacén'>

# %%
mat.plot(kind='scatter',x='PzE',y='Stock máximo')
# Out:
# <AxesSubplot:xlabel='PzE', ylabel='Stock máximo'>

# %%
mat.dtypes
# Out:
# Material                             int64
# UMB                                 object
# Libre utiliz.                      float64
# Punto pedido                       float64
# Stock máximo                       float64
# Tam.lote fijo                        int64
# CaP                                 object
# Texto breve de material             object
# NºMaterial antiguo                  object
# Ce.                                  int64
# Almacén                             object
# PrMedioVar                         float64
# Jquía.productos                     object
# Grupo art.                          object
# Grupo de artículos                  object
# GCp                                 object
# Cantidad base                        int64
# ABC                                 object
# Creado                      datetime64[ns]
# Indicador: Parte crítica            object
# Val.redondeo                       float64
# NºFb                                object
# PzE                                  int64
# stockCero                             bool
# valor                              float64
# dtype: object

# %% [markdown]
# # Introducción al Pandas

# %%
df = pd.read_csv("C:/Users/ordonez/Documents/UCASAL/notebooks/base_datos_2008.csv", nrows = 1000000)

# %%
df.head()

# %%
df.tail()

# %%
df.sample(frac = 1) #El 1 indica que mostrará el 100 %

# %%
#Muestra las columnas del dataFrame
df.columns

# %%
df.info()

# %%
#Para saber el tipo de dato de cada columna
df.dtypes

# %%
df["Year"] #df.Year

# %%
df.Year

# %%
df[['DayofMonth','ArrDelay','Distance']]

# %%
df[df.Origin.isin(["HOU","ATL"])]

# %%
df[pd.isna(df["ArrDelay"])].head()

# %%
len(df[pd.isna(df["ArrDelay"])])

# %% [markdown]
# ## Transformaciones de las bases de datos

# %% [markdown]
# ### Agregamos una columna

# %%
df["HoursDelay"] = round(df["ArrDelay"] / 60)

# %%
df.HoursDelay

# %% [markdown]
# ### Borramos una columna

# %%
del(df["HoursDelay"])

# %%
df = df.drop(["Diverted","Cancelled","Year"],axis=1)
# df.drop(["Diverted","Cancelled","Year"],axis=1,inplace=true) el parámetro inplace hace efectivo el borrado sin necesidad de reasignar

# %%
df.head()

# %% [markdown]
# ### Borrar filas

# %%
df.drop(0) #Borra la primer fila

# %%
df.drop(range(0,10000)) #No borra hasta que se asigne

# %% [markdown]
# ### Concatenating dfATL and dfHOU along rows

# %%
dfATL = df[df.Origin == "ATL"]
dfHOU = df[df.Origin == "HOU"]
newdf = pd.concat([dfATL,dfHOU],axis=0) #dfATL.append(dfHOU) is deprecated

# %%
display(newdf.Origin)

# %% [markdown]
# ### Groupby: Obtener información esencial

# %%
#Obtiene el máximo retraso de los vuelos por semana
df.groupby(by = "DayOfWeek")["ArrDelay"].max()

# %%
df.groupby(by = "DayOfWeek")["ArrDelay"].describe()

# %%
df.groupby(by = "DayOfWeek")["ArrDelay","DepDelay"].mean()

# %%
#Rango
df.groupby(by = "DayOfWeek")["ArrDelay"].max() - df.groupby(by = "DayOfWeek")["ArrDelay"].min()

# %%
dfATLHOU = df[df.Origin.isin(["ATL","HOU"])]

# %%
dfATLHOU.groupby(by = ["DayOfWeek","Origin"])["ArrDelay"].mean()

# %%
mygroupby = dfATLHOU.groupby(by = ["DayOfWeek","Origin"])["ArrDelay"]
mygroupby.max()

# %% [markdown]
# ## Tratar datos duplicados y perdidos

# %%
df = pd.read_csv("C:/Users/ordonez/Documents/UCASAL/notebooks/base_datos_2008.csv", nrows = 1e6)

# %%
#duplicamos el dataframe
dfDuplicate = pd.concat([df,df])

# %%
dfDuplicate = dfDuplicate.sample(frac=1)

# %%
dfClean = dfDuplicate.drop_duplicates()

# %%
dfClean.drop_duplicates(subset = "DayofMonth")

# %%
df.dropna()

# %% [markdown]
# ## Trabajo con Fechas

# %%
dfFechas = pd.DataFrame({'Date':['3/10/2000','3/11/2000','3/12/2000'],
                        'Value':[2,3,4]})

# %%
dfFechas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3 non-null      object
#  1   Value   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
dfFechas['Date'] = pd.to_datetime(dfFechas['Date'])

# %%
dfFechas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3 non-null      datetime64[ns]
#  1   Value   3 non-null      int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 176.0 bytes

# %%
dfFechas
# Out:
#         Date  Value
# 0 2000-03-10      2
# 1 2000-03-11      3
# 2 2000-03-12      4

# %%
dfFechas = pd.DataFrame({'Date':['3/10/2000','3/11/2000','3/12/2000'],
                        'Value':[2,3,4]})
dfFechas['Date'] = pd.to_datetime(dfFechas['Date'], dayfirst=True)

# %%
dfFechas
# Out:
#         Date  Value
# 0 2000-10-03      2
# 1 2000-11-03      3
# 2 2000-12-03      4

# %% [markdown]
# ### Formato personalizado

# %%
df = pd.DataFrame({'date': ['2016-6-10 20:30:0', 
                            '2016-7-1 19:45:30', 
                            '2013-10-12 4:5:1'],
                   'value': [2, 3, 4]})
df['date'] = pd.to_datetime(df['date'], format="%Y-%d-%m %H:%M:%S")

# %%
df
# Out:
#                  date  value
# 0 2016-10-06 20:30:00      2
# 1 2016-01-07 19:45:30      3
# 2 2013-12-10 04:05:01      4

# %%
path = 'https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/'
data = pd.read_csv(path + "titanic.csv")
#data.to_excel("titanic.xlsx")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %%
data
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0      male  22.0                        1                        0   7.2500
# 1    female  38.0                        1                        0  71.2833
# 2    female  26.0                        0                        0   7.9250
# 3    female  35.0                        1                        0  53.1000
# 4      male  35.0                        0                        0   8.0500
# ..      ...   ...                      ...                      ...      ...
# 882    male  27.0                        0                        0  13.0000
# 883  female  19.0                        0                        0  30.0000
# 884  female   7.0                        1                        2  23.4500
# 885    male  26.0                        0                        0  30.0000
# 886    male  32.0                        0                        0   7.7500
#
# [887 rows x 8 columns]

# %% [markdown]
# # Tablas dinámicas

# %%
import pandas as pd
import time

# %%
start = time.time()
df = pd.read_excel("C:/Users/ordonez/Documents/SAP/SAP GUI/M.xlsx")
end = time.time()
print(f'Tardó {end-start} sedundos')
# Out:
# Tardó 6.895370006561279 sedundos

# %%
df.columns
# Out:
# Index(['Material', 'UMB', 'Libre utiliz.', 'Punto pedido', 'Stock máximo',
#        'Tam.lote fijo', 'CaP', 'Texto breve de material', 'NºMaterial antiguo',
#        'Ce.', 'Almacén', 'PrMedioVar', 'Jquía.productos', 'Grupo art.',
#        'Grupo de artículos', 'GCp', 'Cantidad base', 'ABC', 'Creado',
#        'Indicador: Parte crítica', 'Val.redondeo', 'NºFb', 'PzE'],
#       dtype='object')

# %%
tabla_pivote = df.pivot_table(index='Almacén',values='Material',aggfunc='count')

# %%
tabla_pivote
# Out:
#          Material
# Almacén
# 1124        10799
# 1125          702
# 1126         7989
# 1128         7607
# 1129          336
# 1131            9
# 1133            1
# 1137           54
# 1140          264
# 1141          453
# 11JU           63
# 11JV           53

# %% [markdown]
# # Expresiones Regulares

# %%
#Quita los ceros del campo Referencia (Usando expresiones regulres)
#patron = re.compile(r'[1-9]+')

#def eliminarCeros(cadena):
#    respuesta = "*"
#    if not (pd.isna(cadena)):
#        respuesta = "".join(patron.findall(cadena))
#    return respuesta

#bloq['Remitos'] = bloq['Referencia'].apply(eliminarCeros)

# %% [markdown]
# # Delta Degrees of Freedom (para investigar)

# %%
#Delta Degrees of Freedom
calcPto[calcPto['Material']==1004391].iloc[:,2:14].std(axis=1,ddof=0)

# %%
calcPto[calcPto['Material']==1004391].iloc[:,2:14]

# %% [markdown]
# # Para ver indices
# [ver](https://runebook.dev/es/docs/pandas/user_guide/indexing)

# %% [markdown]
# # Best of Both Worlds: Automated and Dynamic SQL Queries from Python
# [link](https://towardsdatascience.com/best-of-both-worlds-automated-and-dynamic-sql-queries-from-python-5b74a24501b0)

# %%
import sqlalchemy as sa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 import sqlalchemy as sa
#
# ModuleNotFoundError: No module named 'sqlalchemy'

# %% [markdown]
# # Fugue and DuckDB: Fast SQL Code in Python
# Optimize Your SQL Code with Python and DuckDB
# [link](https://towardsdatascience.com/fugue-and-duckdb-fast-sql-code-in-python-e2e2dfc0f8eb)

# %% [markdown]
# # 5 Intro to PyTorch: Part 1
# [link](https://towardsdatascience.com/intro-to-pytorch-part-1-663574fb9675)

# %% [markdown]
# ver pyodbc
